# %%
import pickle

# %%
load_model=pickle.load(open('Final_Mul_Linear_Model.sav','rb'))
result=load_model.predict([[10002.23,424153.04,2903.93,False, True]])
result
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[63516.97307525]])
