# %%
import pandas as pd
import warnings as ws

#ws.filterwarnings('ignore')
dataset= pd.read_csv('insurance_pre.csv')
dataset= pd.get_dummies(dataset, drop_first=True)
independent = dataset[['age',  'bmi', 'children', 'sex_male','smoker_yes']]
dependent = dataset[['charges']]
from sklearn.model_selection import train_test_split
X_train,X_test, Y_train, Y_test=train_test_split(independent, dependent, test_size=0.30, random_state=0 )

from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
X_train= sc.fit_transform(X_train)
X_test = sc.transform(X_test)

#from sklearn.svm import SVR
#regressor= SVR()
#regressor = regressor.fit(X_train, Y_train)

from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid={ 'kernel' : ['rbf', 'poly', 'sigmoid', 'scale'], 'C':[10,100,1000,2000,3000],'gamma':['auto', 'scale']}
grid = GridSearchCV(SVR(), param_grid, refit=True, verbose= 3, n_jobs=-1 )
grid.fit(X_train, Y_train)

#print(grid.best_params_)
#re= grid.cv_results_
table =pd.DataFrame.from_dict(re)

# This is method is not need to show, because we got rank wise r2_score value from grid table itself.
#Y_pred = grid.predict(X_test)
#from sklearn.metrics import r2_score
#r2Score = r2_score(Y_test, Y_pred)
#r2Score
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))

pre= grid.predict([[age_input,bmi_input,children_input, sex_male_input, smoker_yes_input]])
pre
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# Age: 34
# BMI: 42.3
# Children: 5
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 1
# array([3709674.49697405])
